# %%
import netCDF4 as nc
from netCDF4 import Dataset
import numpy as np
import json
import subprocess
import os
import sys
#!{sys.executable} -m pip install pyathena
# !{sys.executable} -m pip install PyAthena
from pyathena import connect
import pandas as pd

#
# Rounding error on some columns, example attribute OCDP002
# Stored in Athena as 1.0E-12, rounded to 12 digits.
# Unrouned values in python is 1.472e-12
#
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# ...

# %%
conn = connect(s3_staging_dir='s3://esdis-ems-athena', region_name='us-west-2')
cursor=conn.cursor()

# %%
q="""
insert into sci.merra2_2d_monthly
select
try_cast(ALBEDO  as real) ALBEDO,
try_cast(ALBNIRDF  as real) ALBNIRDF,
try_cast(ALBNIRDR  as real) ALBNIRDR,
try_cast(ALBVISDF  as real) ALBVISDF,
try_cast(ALBVISDR  as real) ALBVISDR,
try_cast(AODANA  as real) AODANA,
try_cast(AODINC  as real) AODINC,
try_cast(BASEFLOW  as real) BASEFLOW,
try_cast(BCANGSTR  as real) BCANGSTR,
try_cast(BCCMASS  as real) BCCMASS,
try_cast(BCDP001  as real) BCDP001,
try_cast(BCDP002  as real) BCDP002,
try_cast(BCEM001  as real) BCEM001,
try_cast(BCEM002  as real) BCEM002,
try_cast(BCEMAN  as real) BCEMAN,
try_cast(BCEMBB  as real) BCEMBB,
try_cast(BCEMBF  as real) BCEMBF,
try_cast(BCEXTTAU  as real) BCEXTTAU,
try_cast(BCFLUXU  as real) BCFLUXU,
try_cast(BCFLUXV  as real) BCFLUXV,
try_cast(BCHYPHIL  as real) BCHYPHIL,
try_cast(BCSCATAU  as real) BCSCATAU,
try_cast(BCSD001  as real) BCSD001,
try_cast(BCSD002  as real) BCSD002,
try_cast(BCSMASS  as real) BCSMASS,
try_cast(BCSV001  as real) BCSV001,
try_cast(BCSV002  as real) BCSV002,
try_cast(BCWT001  as real) BCWT001,
try_cast(BCWT002  as real) BCWT002,
try_cast(BSTAR  as real) BSTAR,
try_cast(CDH  as real) CDH,
try_cast(CDM  as real) CDM,
try_cast(CDQ  as real) CDQ,
try_cast(CLDHGH  as real) CLDHGH,
try_cast(CLDLOW  as real) CLDLOW,
try_cast(CLDMID  as real) CLDMID,
try_cast(CLDPRS  as real) CLDPRS,
try_cast(CLDTMP  as real) CLDTMP,
try_cast(CLDTOT  as real) CLDTOT,
try_cast(CN  as real) CN,
try_cast(COCL  as real) COCL,
try_cast(COEM  as real) COEM,
try_cast(COLS  as real) COLS,
try_cast(COPD  as real) COPD,
try_cast(COSC  as real) COSC,
try_cast(DISPH  as real) DISPH,
try_cast(DMSCMASS  as real) DMSCMASS,
try_cast(DMSSMASS  as real) DMSSMASS,
try_cast(DUAERIDX  as real) DUAERIDX,
try_cast(DUANGSTR  as real) DUANGSTR,
try_cast(DUCMASS  as real) DUCMASS,
try_cast(DUCMASS25  as real) DUCMASS25,
try_cast(DUDP001  as real) DUDP001,
try_cast(DUDP002  as real) DUDP002,
try_cast(DUDP003  as real) DUDP003,
try_cast(DUDP004  as real) DUDP004,
try_cast(DUDP005  as real) DUDP005,
try_cast(DUEM001  as real) DUEM001,
try_cast(DUEM002  as real) DUEM002,
try_cast(DUEM003  as real) DUEM003,
try_cast(DUEM004  as real) DUEM004,
try_cast(DUEM005  as real) DUEM005,
try_cast(DUEXTT25  as real) DUEXTT25,
try_cast(DUEXTTAU  as real) DUEXTTAU,
try_cast(DUEXTTFM  as real) DUEXTTFM,
try_cast(DUFLUXU  as real) DUFLUXU,
try_cast(DUFLUXV  as real) DUFLUXV,
try_cast(DUSCAT25  as real) DUSCAT25,
try_cast(DUSCATAU  as real) DUSCATAU,
try_cast(DUSCATFM  as real) DUSCATFM,
try_cast(DUSD001  as real) DUSD001,
try_cast(DUSD002  as real) DUSD002,
try_cast(DUSD003  as real) DUSD003,
try_cast(DUSD004  as real) DUSD004,
try_cast(DUSD005  as real) DUSD005,
try_cast(DUSMASS  as real) DUSMASS,
try_cast(DUSMASS25  as real) DUSMASS25,
try_cast(DUSV001  as real) DUSV001,
try_cast(DUSV002  as real) DUSV002,
try_cast(DUSV003  as real) DUSV003,
try_cast(DUSV004  as real) DUSV004,
try_cast(DUSV005  as real) DUSV005,
try_cast(DUWT001  as real) DUWT001,
try_cast(DUWT002  as real) DUWT002,
try_cast(DUWT003  as real) DUWT003,
try_cast(DUWT004  as real) DUWT004,
try_cast(DUWT005  as real) DUWT005,
try_cast(ECHANGE  as real) ECHANGE,
try_cast(EFLUX  as real) EFLUX,
try_cast(EFLUXICE  as real) EFLUXICE,
try_cast(EFLUXWTR  as real) EFLUXWTR,
try_cast(EMIS  as real) EMIS,
try_cast(EVAP  as real) EVAP,
try_cast(EVLAND  as real) EVLAND,
try_cast(EVPINTR  as real) EVPINTR,
try_cast(EVPSBLN  as real) EVPSBLN,
try_cast(EVPSOIL  as real) EVPSOIL,
try_cast(EVPTRNS  as real) EVPTRNS,
try_cast(FRCAN  as real) FRCAN,
try_cast(FRCCN  as real) FRCCN,
try_cast(FRCLS  as real) FRCLS,
try_cast(FRSAT  as real) FRSAT,
try_cast(FRSEAICE  as real) FRSEAICE,
try_cast(FRSNO  as real) FRSNO,
try_cast(FRUNST  as real) FRUNST,
try_cast(FRWLT  as real) FRWLT,
try_cast(GHLAND  as real) GHLAND,
try_cast(GHTSKIN  as real) GHTSKIN,
try_cast(GRN  as real) GRN,
try_cast(GWETPROF  as real) GWETPROF,
try_cast(GWETROOT  as real) GWETROOT,
try_cast(GWETTOP  as real) GWETTOP,
try_cast(H1000  as real) H1000,
try_cast(H250  as real) H250,
try_cast(H500  as real) H500,
try_cast(H850  as real) H850,
try_cast(HFLUX  as real) HFLUX,
try_cast(HFLUXICE  as real) HFLUXICE,
try_cast(HFLUXWTR  as real) HFLUXWTR,
try_cast(HLML  as real) HLML,
try_cast(LAI  as real) LAI,
try_cast(LHLAND  as real) LHLAND,
try_cast(LWGAB  as real) LWGAB,
try_cast(LWGABCLR  as real) LWGABCLR,
try_cast(LWGABCLRCLN  as real) LWGABCLRCLN,
try_cast(LWGEM  as real) LWGEM,
try_cast(LWGNT  as real) LWGNT,
try_cast(LWGNTCLR  as real) LWGNTCLR,
try_cast(LWGNTCLRCLN  as real) LWGNTCLRCLN,
try_cast(LWGNTICE  as real) LWGNTICE,
try_cast(LWGNTWTR  as real) LWGNTWTR,
try_cast(LWI  as real) LWI,
try_cast(LWLAND  as real) LWLAND,
try_cast(LWTUP  as real) LWTUP,
try_cast(LWTUPCLR  as real) LWTUPCLR,
try_cast(LWTUPCLRCLN  as real) LWTUPCLRCLN,
try_cast(NIRDF  as real) NIRDF,
try_cast(NIRDR  as real) NIRDR,
try_cast(OCANGSTR  as real) OCANGSTR,
try_cast(OCCMASS  as real) OCCMASS,
try_cast(OCDP001  as real) OCDP001,
try_cast(OCDP002  as real) OCDP002,
try_cast(OCEM001  as real) OCEM001,
try_cast(OCEM002  as real) OCEM002,
try_cast(OCEMAN  as real) OCEMAN,
try_cast(OCEMBB  as real) OCEMBB,
try_cast(OCEMBF  as real) OCEMBF,
try_cast(OCEMBG  as real) OCEMBG,
try_cast(OCEXTTAU  as real) OCEXTTAU,
try_cast(OCFLUXU  as real) OCFLUXU,
try_cast(OCFLUXV  as real) OCFLUXV,
try_cast(OCHYPHIL  as real) OCHYPHIL,
try_cast(OCSCATAU  as real) OCSCATAU,
try_cast(OCSD001  as real) OCSD001,
try_cast(OCSD002  as real) OCSD002,
try_cast(OCSMASS  as real) OCSMASS,
try_cast(OCSV001  as real) OCSV001,
try_cast(OCSV002  as real) OCSV002,
try_cast(OCWT001  as real) OCWT001,
try_cast(OCWT002  as real) OCWT002,
try_cast(OMEGA500  as real) OMEGA500,
try_cast(PARDFLAND  as real) PARDFLAND,
try_cast(PARDRLAND  as real) PARDRLAND,
try_cast(PBLH  as real) PBLH,
try_cast(PBLTOP  as real) PBLTOP,
try_cast(PGENTOT  as real) PGENTOT,
try_cast(PRECANV  as real) PRECANV,
try_cast(PRECCON  as real) PRECCON,
try_cast(PRECLSC  as real) PRECLSC,
try_cast(PRECSNO  as real) PRECSNO,
try_cast(PRECSNOLAND  as real) PRECSNOLAND,
try_cast(PRECSNOOCN  as real) PRECSNOOCN,
try_cast(PRECTOT  as real) PRECTOT,
try_cast(PRECTOTCORR  as real) PRECTOTCORR,
try_cast(PRECTOTLAND  as real) PRECTOTLAND,
try_cast(PREVTOT  as real) PREVTOT,
try_cast(PRMC  as real) PRMC,
try_cast(PS  as real) PS,
try_cast(Q250  as real) Q250,
try_cast(Q500  as real) Q500,
try_cast(Q850  as real) Q850,
try_cast(QINFIL  as real) QINFIL,
try_cast(QLML  as real) QLML,
try_cast(QSH  as real) QSH,
try_cast(QSTAR  as real) QSTAR,
try_cast(QV10M  as real) QV10M,
try_cast(QV2M  as real) QV2M,
try_cast(RAINOCN  as real) RAINOCN,
try_cast(RHOA  as real) RHOA,
try_cast(RISFC  as real) RISFC,
try_cast(RUNOFF  as real) RUNOFF,
try_cast(RZMC  as real) RZMC,
try_cast(SFMC  as real) SFMC,
try_cast(SHLAND  as real) SHLAND,
try_cast(SLP  as real) SLP,
try_cast(SMLAND  as real) SMLAND,
try_cast(SNODP  as real) SNODP,
try_cast(SNOMAS  as real) SNOMAS,
try_cast(SO2CMASS  as real) SO2CMASS,
try_cast(SO2EMAN  as real) SO2EMAN,
try_cast(SO2EMBB  as real) SO2EMBB,
try_cast(SO2EMVE  as real) SO2EMVE,
try_cast(SO2EMVN  as real) SO2EMVN,
try_cast(SO2SMASS  as real) SO2SMASS,
try_cast(SO4CMASS  as real) SO4CMASS,
try_cast(SO4EMAN  as real) SO4EMAN,
try_cast(SO4SMASS  as real) SO4SMASS,
try_cast(SPEED  as real) SPEED,
try_cast(SPEEDMAX  as real) SPEEDMAX,
try_cast(SPLAND  as real) SPLAND,
try_cast(SPSNOW  as real) SPSNOW,
try_cast(SPWATR  as real) SPWATR,
try_cast(SSAERIDX  as real) SSAERIDX,
try_cast(SSANGSTR  as real) SSANGSTR,
try_cast(SSCMASS  as real) SSCMASS,
try_cast(SSCMASS25  as real) SSCMASS25,
try_cast(SSDP001  as real) SSDP001,
try_cast(SSDP002  as real) SSDP002,
try_cast(SSDP003  as real) SSDP003,
try_cast(SSDP004  as real) SSDP004,
try_cast(SSDP005  as real) SSDP005,
try_cast(SSEM001  as real) SSEM001,
try_cast(SSEM002  as real) SSEM002,
try_cast(SSEM003  as real) SSEM003,
try_cast(SSEM004  as real) SSEM004,
try_cast(SSEM005  as real) SSEM005,
try_cast(SSEXTT25  as real) SSEXTT25,
try_cast(SSEXTTAU  as real) SSEXTTAU,
try_cast(SSEXTTFM  as real) SSEXTTFM,
try_cast(SSFLUXU  as real) SSFLUXU,
try_cast(SSFLUXV  as real) SSFLUXV,
try_cast(SSSCAT25  as real) SSSCAT25,
try_cast(SSSCATAU  as real) SSSCATAU,
try_cast(SSSCATFM  as real) SSSCATFM,
try_cast(SSSD001  as real) SSSD001,
try_cast(SSSD002  as real) SSSD002,
try_cast(SSSD003  as real) SSSD003,
try_cast(SSSD004  as real) SSSD004,
try_cast(SSSD005  as real) SSSD005,
try_cast(SSSMASS  as real) SSSMASS,
try_cast(SSSMASS25  as real) SSSMASS25,
try_cast(SSSV001  as real) SSSV001,
try_cast(SSSV002  as real) SSSV002,
try_cast(SSSV003  as real) SSSV003,
try_cast(SSSV004  as real) SSSV004,
try_cast(SSSV005  as real) SSSV005,
try_cast(SSWT001  as real) SSWT001,
try_cast(SSWT002  as real) SSWT002,
try_cast(SSWT003  as real) SSWT003,
try_cast(SSWT004  as real) SSWT004,
try_cast(SSWT005  as real) SSWT005,
try_cast(SUANGSTR  as real) SUANGSTR,
try_cast(SUDP001  as real) SUDP001,
try_cast(SUDP002  as real) SUDP002,
try_cast(SUDP003  as real) SUDP003,
try_cast(SUDP004  as real) SUDP004,
try_cast(SUEM001  as real) SUEM001,
try_cast(SUEM002  as real) SUEM002,
try_cast(SUEM003  as real) SUEM003,
try_cast(SUEM004  as real) SUEM004,
try_cast(SUEXTTAU  as real) SUEXTTAU,
try_cast(SUFLUXU  as real) SUFLUXU,
try_cast(SUFLUXV  as real) SUFLUXV,
try_cast(SUPMSA  as real) SUPMSA,
try_cast(SUPSO2  as real) SUPSO2,
try_cast(SUPSO4AQ  as real) SUPSO4AQ,
try_cast(SUPSO4G  as real) SUPSO4G,
try_cast(SUPSO4WT  as real) SUPSO4WT,
try_cast(SUSCATAU  as real) SUSCATAU,
try_cast(SUSD001  as real) SUSD001,
try_cast(SUSD002  as real) SUSD002,
try_cast(SUSD003  as real) SUSD003,
try_cast(SUSD004  as real) SUSD004,
try_cast(SUSV001  as real) SUSV001,
try_cast(SUSV002  as real) SUSV002,
try_cast(SUSV003  as real) SUSV003,
try_cast(SUSV004  as real) SUSV004,
try_cast(SUWT001  as real) SUWT001,
try_cast(SUWT002  as real) SUWT002,
try_cast(SUWT003  as real) SUWT003,
try_cast(SUWT004  as real) SUWT004,
try_cast(SWGDN  as real) SWGDN,
try_cast(SWGDNCLR  as real) SWGDNCLR,
try_cast(SWGNT  as real) SWGNT,
try_cast(SWGNTCLN  as real) SWGNTCLN,
try_cast(SWGNTCLR  as real) SWGNTCLR,
try_cast(SWGNTCLRCLN  as real) SWGNTCLRCLN,
try_cast(SWGNTICE  as real) SWGNTICE,
try_cast(SWGNTWTR  as real) SWGNTWTR,
try_cast(SWLAND  as real) SWLAND,
try_cast(SWTDN  as real) SWTDN,
try_cast(SWTNT  as real) SWTNT,
try_cast(SWTNTCLN  as real) SWTNTCLN,
try_cast(SWTNTCLR  as real) SWTNTCLR,
try_cast(SWTNTCLRCLN  as real) SWTNTCLRCLN,
try_cast(T10M  as real) T10M,
try_cast(T250  as real) T250,
try_cast(T2M  as real) T2M,
try_cast(T2MDEW  as real) T2MDEW,
try_cast(T2MWET  as real) T2MWET,
try_cast(T500  as real) T500,
try_cast(T850  as real) T850,
try_cast(TAUGWX  as real) TAUGWX,
try_cast(TAUGWY  as real) TAUGWY,
try_cast(TAUHGH  as real) TAUHGH,
try_cast(TAULOW  as real) TAULOW,
try_cast(TAUMID  as real) TAUMID,
try_cast(TAUTOT  as real) TAUTOT,
try_cast(TAUX  as real) TAUX,
try_cast(TAUXICE  as real) TAUXICE,
try_cast(TAUXWTR  as real) TAUXWTR,
try_cast(TAUY  as real) TAUY,
try_cast(TAUYICE  as real) TAUYICE,
try_cast(TAUYWTR  as real) TAUYWTR,
try_cast(TCZPBL  as real) TCZPBL,
try_cast(TELAND  as real) TELAND,
try_cast(TLML  as real) TLML,
try_cast(TO3  as real) TO3,
try_cast(TOTANGSTR  as real) TOTANGSTR,
try_cast(TOTEXTTAU  as real) TOTEXTTAU,
try_cast(TOTSCATAU  as real) TOTSCATAU,
try_cast(TOX  as real) TOX,
try_cast(TPSNOW  as real) TPSNOW,
try_cast(TQI  as real) TQI,
try_cast(TQL  as real) TQL,
try_cast(TQV  as real) TQV,
try_cast(TROPPB  as real) TROPPB,
try_cast(TROPPT  as real) TROPPT,
try_cast(TROPPV  as real) TROPPV,
try_cast(TROPQ  as real) TROPQ,
try_cast(TROPT  as real) TROPT,
try_cast(TS  as real) TS,
try_cast(TSAT  as real) TSAT,
try_cast(TSH  as real) TSH,
try_cast(TSKINICE  as real) TSKINICE,
try_cast(TSKINWTR  as real) TSKINWTR,
try_cast(TSOIL1  as real) TSOIL1,
try_cast(TSOIL2  as real) TSOIL2,
try_cast(TSOIL3  as real) TSOIL3,
try_cast(TSOIL4  as real) TSOIL4,
try_cast(TSOIL5  as real) TSOIL5,
try_cast(TSOIL6  as real) TSOIL6,
try_cast(TSTAR  as real) TSTAR,
try_cast(TSURF  as real) TSURF,
try_cast(TUNST  as real) TUNST,
try_cast(TWLAND  as real) TWLAND,
try_cast(TWLT  as real) TWLT,
try_cast(U10M  as real) U10M,
try_cast(U250  as real) U250,
try_cast(U2M  as real) U2M,
try_cast(U500  as real) U500,
try_cast(U50M  as real) U50M,
try_cast(U850  as real) U850,
try_cast(ULML  as real) ULML,
try_cast(USTAR  as real) USTAR,
try_cast(V10M  as real) V10M,
try_cast(V250  as real) V250,
try_cast(V2M  as real) V2M,
try_cast(V500  as real) V500,
try_cast(V50M  as real) V50M,
try_cast(V850  as real) V850,
try_cast(VLML  as real) VLML,
try_cast(Var_ALBEDO  as real) Var_ALBEDO,
try_cast(Var_ALBNIRDF  as real) Var_ALBNIRDF,
try_cast(Var_ALBNIRDR  as real) Var_ALBNIRDR,
try_cast(Var_ALBVISDF  as real) Var_ALBVISDF,
try_cast(Var_ALBVISDR  as real) Var_ALBVISDR,
try_cast(Var_AODANA  as real) Var_AODANA,
try_cast(Var_AODINC  as real) Var_AODINC,
try_cast(Var_BASEFLOW  as real) Var_BASEFLOW,
try_cast(Var_BCANGSTR  as real) Var_BCANGSTR,
try_cast(Var_BCCMASS  as real) Var_BCCMASS,
try_cast(Var_BCDP001  as real) Var_BCDP001,
try_cast(Var_BCDP002  as real) Var_BCDP002,
try_cast(Var_BCEM001  as real) Var_BCEM001,
try_cast(Var_BCEM002  as real) Var_BCEM002,
try_cast(Var_BCEMAN  as real) Var_BCEMAN,
try_cast(Var_BCEMBB  as real) Var_BCEMBB,
try_cast(Var_BCEMBF  as real) Var_BCEMBF,
try_cast(Var_BCEXTTAU  as real) Var_BCEXTTAU,
try_cast(Var_BCFLUXU  as real) Var_BCFLUXU,
try_cast(Var_BCFLUXV  as real) Var_BCFLUXV,
try_cast(Var_BCHYPHIL  as real) Var_BCHYPHIL,
try_cast(Var_BCSCATAU  as real) Var_BCSCATAU,
try_cast(Var_BCSD001  as real) Var_BCSD001,
try_cast(Var_BCSD002  as real) Var_BCSD002,
try_cast(Var_BCSMASS  as real) Var_BCSMASS,
try_cast(Var_BCSV001  as real) Var_BCSV001,
try_cast(Var_BCSV002  as real) Var_BCSV002,
try_cast(Var_BCWT001  as real) Var_BCWT001,
try_cast(Var_BCWT002  as real) Var_BCWT002,
try_cast(Var_BSTAR  as real) Var_BSTAR,
try_cast(Var_CDH  as real) Var_CDH,
try_cast(Var_CDM  as real) Var_CDM,
try_cast(Var_CDQ  as real) Var_CDQ,
try_cast(Var_CLDHGH  as real) Var_CLDHGH,
try_cast(Var_CLDLOW  as real) Var_CLDLOW,
try_cast(Var_CLDMID  as real) Var_CLDMID,
try_cast(Var_CLDPRS  as real) Var_CLDPRS,
try_cast(Var_CLDTMP  as real) Var_CLDTMP,
try_cast(Var_CLDTOT  as real) Var_CLDTOT,
try_cast(Var_CN  as real) Var_CN,
try_cast(Var_COCL  as real) Var_COCL,
try_cast(Var_COEM  as real) Var_COEM,
try_cast(Var_COLS  as real) Var_COLS,
try_cast(Var_COPD  as real) Var_COPD,
try_cast(Var_COSC  as real) Var_COSC,
try_cast(Var_DISPH  as real) Var_DISPH,
try_cast(Var_DMSCMASS  as real) Var_DMSCMASS,
try_cast(Var_DMSSMASS  as real) Var_DMSSMASS,
try_cast(Var_DUAERIDX  as real) Var_DUAERIDX,
try_cast(Var_DUANGSTR  as real) Var_DUANGSTR,
try_cast(Var_DUCMASS  as real) Var_DUCMASS,
try_cast(Var_DUCMASS25  as real) Var_DUCMASS25,
try_cast(Var_DUDP001  as real) Var_DUDP001,
try_cast(Var_DUDP002  as real) Var_DUDP002,
try_cast(Var_DUDP003  as real) Var_DUDP003,
try_cast(Var_DUDP004  as real) Var_DUDP004,
try_cast(Var_DUDP005  as real) Var_DUDP005,
try_cast(Var_DUEM001  as real) Var_DUEM001,
try_cast(Var_DUEM002  as real) Var_DUEM002,
try_cast(Var_DUEM003  as real) Var_DUEM003,
try_cast(Var_DUEM004  as real) Var_DUEM004,
try_cast(Var_DUEM005  as real) Var_DUEM005,
try_cast(Var_DUEXTT25  as real) Var_DUEXTT25,
try_cast(Var_DUEXTTAU  as real) Var_DUEXTTAU,
try_cast(Var_DUEXTTFM  as real) Var_DUEXTTFM,
try_cast(Var_DUFLUXU  as real) Var_DUFLUXU,
try_cast(Var_DUFLUXV  as real) Var_DUFLUXV,
try_cast(Var_DUSCAT25  as real) Var_DUSCAT25,
try_cast(Var_DUSCATAU  as real) Var_DUSCATAU,
try_cast(Var_DUSCATFM  as real) Var_DUSCATFM,
try_cast(Var_DUSD001  as real) Var_DUSD001,
try_cast(Var_DUSD002  as real) Var_DUSD002,
try_cast(Var_DUSD003  as real) Var_DUSD003,
try_cast(Var_DUSD004  as real) Var_DUSD004,
try_cast(Var_DUSD005  as real) Var_DUSD005,
try_cast(Var_DUSMASS  as real) Var_DUSMASS,
try_cast(Var_DUSMASS25  as real) Var_DUSMASS25,
try_cast(Var_DUSV001  as real) Var_DUSV001,
try_cast(Var_DUSV002  as real) Var_DUSV002,
try_cast(Var_DUSV003  as real) Var_DUSV003,
try_cast(Var_DUSV004  as real) Var_DUSV004,
try_cast(Var_DUSV005  as real) Var_DUSV005,
try_cast(Var_DUWT001  as real) Var_DUWT001,
try_cast(Var_DUWT002  as real) Var_DUWT002,
try_cast(Var_DUWT003  as real) Var_DUWT003,
try_cast(Var_DUWT004  as real) Var_DUWT004,
try_cast(Var_DUWT005  as real) Var_DUWT005,
try_cast(Var_ECHANGE  as real) Var_ECHANGE,
try_cast(Var_EFLUX  as real) Var_EFLUX,
try_cast(Var_EFLUXICE  as real) Var_EFLUXICE,
try_cast(Var_EFLUXWTR  as real) Var_EFLUXWTR,
try_cast(Var_EMIS  as real) Var_EMIS,
try_cast(Var_EVAP  as real) Var_EVAP,
try_cast(Var_EVLAND  as real) Var_EVLAND,
try_cast(Var_EVPINTR  as real) Var_EVPINTR,
try_cast(Var_EVPSBLN  as real) Var_EVPSBLN,
try_cast(Var_EVPSOIL  as real) Var_EVPSOIL,
try_cast(Var_EVPTRNS  as real) Var_EVPTRNS,
try_cast(Var_FRCAN  as real) Var_FRCAN,
try_cast(Var_FRCCN  as real) Var_FRCCN,
try_cast(Var_FRCLS  as real) Var_FRCLS,
try_cast(Var_FRSAT  as real) Var_FRSAT,
try_cast(Var_FRSEAICE  as real) Var_FRSEAICE,
try_cast(Var_FRSNO  as real) Var_FRSNO,
try_cast(Var_FRUNST  as real) Var_FRUNST,
try_cast(Var_FRWLT  as real) Var_FRWLT,
try_cast(Var_GHLAND  as real) Var_GHLAND,
try_cast(Var_GHTSKIN  as real) Var_GHTSKIN,
try_cast(Var_GRN  as real) Var_GRN,
try_cast(Var_GWETPROF  as real) Var_GWETPROF,
try_cast(Var_GWETROOT  as real) Var_GWETROOT,
try_cast(Var_GWETTOP  as real) Var_GWETTOP,
try_cast(Var_H1000  as real) Var_H1000,
try_cast(Var_H250  as real) Var_H250,
try_cast(Var_H500  as real) Var_H500,
try_cast(Var_H850  as real) Var_H850,
try_cast(Var_HFLUX  as real) Var_HFLUX,
try_cast(Var_HFLUXICE  as real) Var_HFLUXICE,
try_cast(Var_HFLUXWTR  as real) Var_HFLUXWTR,
try_cast(Var_HLML  as real) Var_HLML,
try_cast(Var_LAI  as real) Var_LAI,
try_cast(Var_LHLAND  as real) Var_LHLAND,
try_cast(Var_LWGAB  as real) Var_LWGAB,
try_cast(Var_LWGABCLR  as real) Var_LWGABCLR,
try_cast(Var_LWGABCLRCLN  as real) Var_LWGABCLRCLN,
try_cast(Var_LWGEM  as real) Var_LWGEM,
try_cast(Var_LWGNT  as real) Var_LWGNT,
try_cast(Var_LWGNTCLR  as real) Var_LWGNTCLR,
try_cast(Var_LWGNTCLRCLN  as real) Var_LWGNTCLRCLN,
try_cast(Var_LWGNTICE  as real) Var_LWGNTICE,
try_cast(Var_LWGNTWTR  as real) Var_LWGNTWTR,
try_cast(Var_LWI  as real) Var_LWI,
try_cast(Var_LWLAND  as real) Var_LWLAND,
try_cast(Var_LWTUP  as real) Var_LWTUP,
try_cast(Var_LWTUPCLR  as real) Var_LWTUPCLR,
try_cast(Var_LWTUPCLRCLN  as real) Var_LWTUPCLRCLN,
try_cast(Var_NIRDF  as real) Var_NIRDF,
try_cast(Var_NIRDR  as real) Var_NIRDR,
try_cast(Var_OCANGSTR  as real) Var_OCANGSTR,
try_cast(Var_OCCMASS  as real) Var_OCCMASS,
try_cast(Var_OCDP001  as real) Var_OCDP001,
try_cast(Var_OCDP002  as real) Var_OCDP002,
try_cast(Var_OCEM001  as real) Var_OCEM001,
try_cast(Var_OCEM002  as real) Var_OCEM002,
try_cast(Var_OCEMAN  as real) Var_OCEMAN,
try_cast(Var_OCEMBB  as real) Var_OCEMBB,
try_cast(Var_OCEMBF  as real) Var_OCEMBF,
try_cast(Var_OCEMBG  as real) Var_OCEMBG,
try_cast(Var_OCEXTTAU  as real) Var_OCEXTTAU,
try_cast(Var_OCFLUXU  as real) Var_OCFLUXU,
try_cast(Var_OCFLUXV  as real) Var_OCFLUXV,
try_cast(Var_OCHYPHIL  as real) Var_OCHYPHIL,
try_cast(Var_OCSCATAU  as real) Var_OCSCATAU,
try_cast(Var_OCSD001  as real) Var_OCSD001,
try_cast(Var_OCSD002  as real) Var_OCSD002,
try_cast(Var_OCSMASS  as real) Var_OCSMASS,
try_cast(Var_OCSV001  as real) Var_OCSV001,
try_cast(Var_OCSV002  as real) Var_OCSV002,
try_cast(Var_OCWT001  as real) Var_OCWT001,
try_cast(Var_OCWT002  as real) Var_OCWT002,
try_cast(Var_OMEGA500  as real) Var_OMEGA500,
try_cast(Var_PARDFLAND  as real) Var_PARDFLAND,
try_cast(Var_PARDRLAND  as real) Var_PARDRLAND,
try_cast(Var_PBLH  as real) Var_PBLH,
try_cast(Var_PBLTOP  as real) Var_PBLTOP,
try_cast(Var_PGENTOT  as real) Var_PGENTOT,
try_cast(Var_PRECANV  as real) Var_PRECANV,
try_cast(Var_PRECCON  as real) Var_PRECCON,
try_cast(Var_PRECLSC  as real) Var_PRECLSC,
try_cast(Var_PRECSNO  as real) Var_PRECSNO,
try_cast(Var_PRECSNOLAND  as real) Var_PRECSNOLAND,
try_cast(Var_PRECSNOOCN  as real) Var_PRECSNOOCN,
try_cast(Var_PRECTOT  as real) Var_PRECTOT,
try_cast(Var_PRECTOTCORR  as real) Var_PRECTOTCORR,
try_cast(Var_PRECTOTLAND  as real) Var_PRECTOTLAND,
try_cast(Var_PREVTOT  as real) Var_PREVTOT,
try_cast(Var_PRMC  as real) Var_PRMC,
try_cast(Var_PS  as real) Var_PS,
try_cast(Var_Q250  as real) Var_Q250,
try_cast(Var_Q500  as real) Var_Q500,
try_cast(Var_Q850  as real) Var_Q850,
try_cast(Var_QINFIL  as real) Var_QINFIL,
try_cast(Var_QLML  as real) Var_QLML,
try_cast(Var_QSH  as real) Var_QSH,
try_cast(Var_QSTAR  as real) Var_QSTAR,
try_cast(Var_QV10M  as real) Var_QV10M,
try_cast(Var_QV2M  as real) Var_QV2M,
try_cast(Var_RAINOCN  as real) Var_RAINOCN,
try_cast(Var_RHOA  as real) Var_RHOA,
try_cast(Var_RISFC  as real) Var_RISFC,
try_cast(Var_RUNOFF  as real) Var_RUNOFF,
try_cast(Var_RZMC  as real) Var_RZMC,
try_cast(Var_SFMC  as real) Var_SFMC,
try_cast(Var_SHLAND  as real) Var_SHLAND,
try_cast(Var_SLP  as real) Var_SLP,
try_cast(Var_SMLAND  as real) Var_SMLAND,
try_cast(Var_SNODP  as real) Var_SNODP,
try_cast(Var_SNOMAS  as real) Var_SNOMAS,
try_cast(Var_SO2CMASS  as real) Var_SO2CMASS,
try_cast(Var_SO2EMAN  as real) Var_SO2EMAN,
try_cast(Var_SO2EMBB  as real) Var_SO2EMBB,
try_cast(Var_SO2EMVE  as real) Var_SO2EMVE,
try_cast(Var_SO2EMVN  as real) Var_SO2EMVN,
try_cast(Var_SO2SMASS  as real) Var_SO2SMASS,
try_cast(Var_SO4CMASS  as real) Var_SO4CMASS,
try_cast(Var_SO4EMAN  as real) Var_SO4EMAN,
try_cast(Var_SO4SMASS  as real) Var_SO4SMASS,
try_cast(Var_SPEED  as real) Var_SPEED,
try_cast(Var_SPEEDMAX  as real) Var_SPEEDMAX,
try_cast(Var_SPLAND  as real) Var_SPLAND,
try_cast(Var_SPSNOW  as real) Var_SPSNOW,
try_cast(Var_SPWATR  as real) Var_SPWATR,
try_cast(Var_SSAERIDX  as real) Var_SSAERIDX,
try_cast(Var_SSANGSTR  as real) Var_SSANGSTR,
try_cast(Var_SSCMASS  as real) Var_SSCMASS,
try_cast(Var_SSCMASS25  as real) Var_SSCMASS25,
try_cast(Var_SSDP001  as real) Var_SSDP001,
try_cast(Var_SSDP002  as real) Var_SSDP002,
try_cast(Var_SSDP003  as real) Var_SSDP003,
try_cast(Var_SSDP004  as real) Var_SSDP004,
try_cast(Var_SSDP005  as real) Var_SSDP005,
try_cast(Var_SSEM001  as real) Var_SSEM001,
try_cast(Var_SSEM002  as real) Var_SSEM002,
try_cast(Var_SSEM003  as real) Var_SSEM003,
try_cast(Var_SSEM004  as real) Var_SSEM004,
try_cast(Var_SSEM005  as real) Var_SSEM005,
try_cast(Var_SSEXTT25  as real) Var_SSEXTT25,
try_cast(Var_SSEXTTAU  as real) Var_SSEXTTAU,
try_cast(Var_SSEXTTFM  as real) Var_SSEXTTFM,
try_cast(Var_SSFLUXU  as real) Var_SSFLUXU,
try_cast(Var_SSFLUXV  as real) Var_SSFLUXV,
try_cast(Var_SSSCAT25  as real) Var_SSSCAT25,
try_cast(Var_SSSCATAU  as real) Var_SSSCATAU,
try_cast(Var_SSSCATFM  as real) Var_SSSCATFM,
try_cast(Var_SSSD001  as real) Var_SSSD001,
try_cast(Var_SSSD002  as real) Var_SSSD002,
try_cast(Var_SSSD003  as real) Var_SSSD003,
try_cast(Var_SSSD004  as real) Var_SSSD004,
try_cast(Var_SSSD005  as real) Var_SSSD005,
try_cast(Var_SSSMASS  as real) Var_SSSMASS,
try_cast(Var_SSSMASS25  as real) Var_SSSMASS25,
try_cast(Var_SSSV001  as real) Var_SSSV001,
try_cast(Var_SSSV002  as real) Var_SSSV002,
try_cast(Var_SSSV003  as real) Var_SSSV003,
try_cast(Var_SSSV004  as real) Var_SSSV004,
try_cast(Var_SSSV005  as real) Var_SSSV005,
try_cast(Var_SSWT001  as real) Var_SSWT001,
try_cast(Var_SSWT002  as real) Var_SSWT002,
try_cast(Var_SSWT003  as real) Var_SSWT003,
try_cast(Var_SSWT004  as real) Var_SSWT004,
try_cast(Var_SSWT005  as real) Var_SSWT005,
try_cast(Var_SUANGSTR  as real) Var_SUANGSTR,
try_cast(Var_SUDP001  as real) Var_SUDP001,
try_cast(Var_SUDP002  as real) Var_SUDP002,
try_cast(Var_SUDP003  as real) Var_SUDP003,
try_cast(Var_SUDP004  as real) Var_SUDP004,
try_cast(Var_SUEM001  as real) Var_SUEM001,
try_cast(Var_SUEM002  as real) Var_SUEM002,
try_cast(Var_SUEM003  as real) Var_SUEM003,
try_cast(Var_SUEM004  as real) Var_SUEM004,
try_cast(Var_SUEXTTAU  as real) Var_SUEXTTAU,
try_cast(Var_SUFLUXU  as real) Var_SUFLUXU,
try_cast(Var_SUFLUXV  as real) Var_SUFLUXV,
try_cast(Var_SUPMSA  as real) Var_SUPMSA,
try_cast(Var_SUPSO2  as real) Var_SUPSO2,
try_cast(Var_SUPSO4AQ  as real) Var_SUPSO4AQ,
try_cast(Var_SUPSO4G  as real) Var_SUPSO4G,
try_cast(Var_SUPSO4WT  as real) Var_SUPSO4WT,
try_cast(Var_SUSCATAU  as real) Var_SUSCATAU,
try_cast(Var_SUSD001  as real) Var_SUSD001,
try_cast(Var_SUSD002  as real) Var_SUSD002,
try_cast(Var_SUSD003  as real) Var_SUSD003,
try_cast(Var_SUSD004  as real) Var_SUSD004,
try_cast(Var_SUSV001  as real) Var_SUSV001,
try_cast(Var_SUSV002  as real) Var_SUSV002,
try_cast(Var_SUSV003  as real) Var_SUSV003,
try_cast(Var_SUSV004  as real) Var_SUSV004,
try_cast(Var_SUWT001  as real) Var_SUWT001,
try_cast(Var_SUWT002  as real) Var_SUWT002,
try_cast(Var_SUWT003  as real) Var_SUWT003,
try_cast(Var_SUWT004  as real) Var_SUWT004,
try_cast(Var_SWGDN  as real) Var_SWGDN,
try_cast(Var_SWGDNCLR  as real) Var_SWGDNCLR,
try_cast(Var_SWGNT  as real) Var_SWGNT,
try_cast(Var_SWGNTCLN  as real) Var_SWGNTCLN,
try_cast(Var_SWGNTCLR  as real) Var_SWGNTCLR,
try_cast(Var_SWGNTCLRCLN  as real) Var_SWGNTCLRCLN,
try_cast(Var_SWGNTICE  as real) Var_SWGNTICE,
try_cast(Var_SWGNTWTR  as real) Var_SWGNTWTR,
try_cast(Var_SWLAND  as real) Var_SWLAND,
try_cast(Var_SWTDN  as real) Var_SWTDN,
try_cast(Var_SWTNT  as real) Var_SWTNT,
try_cast(Var_SWTNTCLN  as real) Var_SWTNTCLN,
try_cast(Var_SWTNTCLR  as real) Var_SWTNTCLR,
try_cast(Var_SWTNTCLRCLN  as real) Var_SWTNTCLRCLN,
try_cast(Var_T10M  as real) Var_T10M,
try_cast(Var_T250  as real) Var_T250,
try_cast(Var_T2M  as real) Var_T2M,
try_cast(Var_T2MDEW  as real) Var_T2MDEW,
try_cast(Var_T2MWET  as real) Var_T2MWET,
try_cast(Var_T500  as real) Var_T500,
try_cast(Var_T850  as real) Var_T850,
try_cast(Var_TAUGWX  as real) Var_TAUGWX,
try_cast(Var_TAUGWY  as real) Var_TAUGWY,
try_cast(Var_TAUHGH  as real) Var_TAUHGH,
try_cast(Var_TAULOW  as real) Var_TAULOW,
try_cast(Var_TAUMID  as real) Var_TAUMID,
try_cast(Var_TAUTOT  as real) Var_TAUTOT,
try_cast(Var_TAUX  as real) Var_TAUX,
try_cast(Var_TAUXICE  as real) Var_TAUXICE,
try_cast(Var_TAUXWTR  as real) Var_TAUXWTR,
try_cast(Var_TAUY  as real) Var_TAUY,
try_cast(Var_TAUYICE  as real) Var_TAUYICE,
try_cast(Var_TAUYWTR  as real) Var_TAUYWTR,
try_cast(Var_TCZPBL  as real) Var_TCZPBL,
try_cast(Var_TELAND  as real) Var_TELAND,
try_cast(Var_TLML  as real) Var_TLML,
try_cast(Var_TO3  as real) Var_TO3,
try_cast(Var_TOTANGSTR  as real) Var_TOTANGSTR,
try_cast(Var_TOTEXTTAU  as real) Var_TOTEXTTAU,
try_cast(Var_TOTSCATAU  as real) Var_TOTSCATAU,
try_cast(Var_TOX  as real) Var_TOX,
try_cast(Var_TPSNOW  as real) Var_TPSNOW,
try_cast(Var_TQI  as real) Var_TQI,
try_cast(Var_TQL  as real) Var_TQL,
try_cast(Var_TQV  as real) Var_TQV,
try_cast(Var_TROPPB  as real) Var_TROPPB,
try_cast(Var_TROPPT  as real) Var_TROPPT,
try_cast(Var_TROPPV  as real) Var_TROPPV,
try_cast(Var_TROPQ  as real) Var_TROPQ,
try_cast(Var_TROPT  as real) Var_TROPT,
try_cast(Var_TS  as real) Var_TS,
try_cast(Var_TSAT  as real) Var_TSAT,
try_cast(Var_TSH  as real) Var_TSH,
try_cast(Var_TSKINICE  as real) Var_TSKINICE,
try_cast(Var_TSKINWTR  as real) Var_TSKINWTR,
try_cast(Var_TSOIL1  as real) Var_TSOIL1,
try_cast(Var_TSOIL2  as real) Var_TSOIL2,
try_cast(Var_TSOIL3  as real) Var_TSOIL3,
try_cast(Var_TSOIL4  as real) Var_TSOIL4,
try_cast(Var_TSOIL5  as real) Var_TSOIL5,
try_cast(Var_TSOIL6  as real) Var_TSOIL6,
try_cast(Var_TSTAR  as real) Var_TSTAR,
try_cast(Var_TSURF  as real) Var_TSURF,
try_cast(Var_TUNST  as real) Var_TUNST,
try_cast(Var_TWLAND  as real) Var_TWLAND,
try_cast(Var_TWLT  as real) Var_TWLT,
try_cast(Var_U10M  as real) Var_U10M,
try_cast(Var_U250  as real) Var_U250,
try_cast(Var_U2M  as real) Var_U2M,
try_cast(Var_U500  as real) Var_U500,
try_cast(Var_U50M  as real) Var_U50M,
try_cast(Var_U850  as real) Var_U850,
try_cast(Var_ULML  as real) Var_ULML,
try_cast(Var_USTAR  as real) Var_USTAR,
try_cast(Var_V10M  as real) Var_V10M,
try_cast(Var_V250  as real) Var_V250,
try_cast(Var_V2M  as real) Var_V2M,
try_cast(Var_V500  as real) Var_V500,
try_cast(Var_V50M  as real) Var_V50M,
try_cast(Var_V850  as real) Var_V850,
try_cast(Var_VLML  as real) Var_VLML,
try_cast(Var_WCHANGE  as real) Var_WCHANGE,
try_cast(Var_Z0H  as real) Var_Z0H,
try_cast(Var_Z0M  as real) Var_Z0M,
try_cast(Var_ZLCL  as real) Var_ZLCL,
try_cast(WCHANGE  as real) WCHANGE,
try_cast(Z0H  as real) Z0H,
try_cast(Z0M  as real) Z0M,
try_cast(ZLCL  as real) ZLCL,
try_cast(lat  as real) lat,
try_cast(lon  as real) lon,
date_add('second', try_cast(try_cast(time  as real) as bigint), timestamp '1970-01-01 00:00:00') time
from sci_staging.merra_2d_month
order by try_cast(lon as real)
"""

# %%
inputs={}
f = open("gesdisc_merra2_monthly_urls.txt", "r")
x=f.read()
f.close()

urls=x.split('\n')
for u in urls:
    if len(u) == 0:
        continue
    #print (u)
    fileName=(u[u.rindex('/')+1:])
    fparts = fileName.split('.')
    #print (fparts)
    sortkey = fparts[2]
    dskey   = fparts[1]
    if sortkey in inputs:
        inputs[sortkey][dskey]['url']=u
        inputs[sortkey][dskey]['fn']=fileName
    else:
        inputs[sortkey]= {
    "tavgM_2d_adg_Nx" : { "url" : "", "fn" : ""},
    "tavgM_2d_aer_Nx" : { "url" : "", "fn" : ""},
    "tavgM_2d_chm_Nx" : { "url" : "", "fn" : ""},
    "tavgM_2d_flx_Nx" : { "url" : "", "fn" : ""},
    "instM_2d_gas_Nx" : { "url" : "", "fn" : ""},
    "tavgM_2d_lnd_Nx" : { "url" : "", "fn" : ""},
    "tavgM_2d_ocn_Nx" : { "url" : "", "fn" : ""},
    "tavgM_2d_rad_Nx" : { "url" : "", "fn" : ""},
    "tavgM_2d_slv_Nx" : { "url" : "", "fn" : ""}
  }
        inputs[sortkey][dskey]['url']=u
        inputs[sortkey][dskey]['fn']=fileName

# %%
def do_it(m_str, m):
    #print (m['tavgM_2d_adg_Nx'])
    vars={}
    for d in m:
        ds=m[d]['ds']
        for v in ds.variables:
            if v in vars:
                print ('duplicate variable: ', v, ' skipping ....')
            else:
                ds.set_auto_mask(False)
                if '_FillValue' in ds[v].ncattrs():
                    tmp=ds[v][:]
                    tmp[tmp == ds[v]._FillValue] = np.nan
                    vars[v]=tmp[:]
                else:
                    vars[v]=ds[v][:]
        print (d)
        
# Normalize lat/lon
    vm_lon, vm_lat = np.meshgrid(vars['lon'], vars['lat'])
    print (vm_lat.shape, vm_lon)

# Normalize time

    v_time = nc.num2date(vars['time'][:],ds['time'].units, only_use_python_datetimes=True)
    print (v_time)
    vm_time=np.zeros(207936, dtype='datetime64[s]')
    vm_time[:]= v_time

    print (vm_time[0])

# string for filename
    s_time=[]
    for t in v_time:
        s_time.append(t.strftime("%Y-%m-%d %H:%M:%S").replace( ' ', 'T'))
    print (s_time)


    t_size=vars['time'].size
    for t in range(t_size):
        #print (t)
        stack_this = []
        ctr=0
        for v in sorted(vars):
            #print (ctr, v, vars[v].shape)
            ctr+=1
            if v == 'time':
                vm_time[:] = vm_time
                print ('vmtime', vm_time.shape)
                stack_this.append(vm_time.astype('float'))
            elif v == 'lon':
                stack_this.append(vm_lon.flatten()[:])
            elif v == 'lat':
                stack_this.append(vm_lat.flatten()[:])
            else:
                stack_this.append(vars[v][t].flatten()[:])
        #print (stack_this)
        x=np.dstack( (stack_this) )
        fname = '/home/ec2-user/merra2-2d_monthly_' + m_str + '.tsv.gz'
        np.savetxt(fname, x[0], fmt='%.12f', delimiter='~', newline="\n")        
        
    return

# %%
for m in inputs:
    if m <= '202101':
        continue
    print (m)
    for d in inputs[m]:
        #print (m, d)
        print (inputs[m][d]['url'], inputs[m][d]['fn'])
        subprocess.run(["curl", "-n", "-c", ".urs_cookies", "-b", ".urs_cookies", "-LJO", "--url", inputs[m][d]['url']])
        inputs[m][d]['ds']=Dataset(inputs[m][d]['fn'])
    break
    do_it(m, inputs[m]) # Create monthly tsv.gz files
    
    for d in inputs[m]:
        inputs[m][d]['ds'].close()
        os.remove(inputs[m][d]['fn'])
        
    stagingS3  = 's3://nasa-ems-sandbox/staging/science/merra-2/2d_1hr/'
    for f in outs:
        rc=subprocess.run(["aws", "s3", "cp", f, stagingS3 ])
#    print ('rc:', rc)
    # Execute insert into ...
    cursor.execute(q)
    print(cursor.description)
    print(cursor.fetchall())
    
    for f in outs:
        
    # Delete s3 staging files
        rc=subprocess.run(["aws", "s3", "rm", stagingS3 + f.rsplit('/', 1)[-1]])
        print ('rc:',rc)
     
    # Delete tsv.gz file(s)
        os.remove(f)
# Out:
# 202102
# https://goldsmr4.gesdisc.eosdis.nasa.gov/data/MERRA2_MONTHLY/M2TMNXADG.5.12.4/2021/MERRA2_400.tavgM_2d_adg_Nx.202102.nc4 MERRA2_400.tavgM_2d_adg_Nx.202102.nc4
# https://goldsmr4.gesdisc.eosdis.nasa.gov/data/MERRA2_MONTHLY/M2TMNXAER.5.12.4/2021/MERRA2_400.tavgM_2d_aer_Nx.202102.nc4 MERRA2_400.tavgM_2d_aer_Nx.202102.nc4
# https://goldsmr4.gesdisc.eosdis.nasa.gov/data/MERRA2_MONTHLY/M2TMNXCHM.5.12.4/2021/MERRA2_400.tavgM_2d_chm_Nx.202102.nc4 MERRA2_400.tavgM_2d_chm_Nx.202102.nc4
# https://goldsmr4.gesdisc.eosdis.nasa.gov/data/MERRA2_MONTHLY/M2TMNXFLX.5.12.4/2021/MERRA2_400.tavgM_2d_flx_Nx.202102.nc4 MERRA2_400.tavgM_2d_flx_Nx.202102.nc4
# https://goldsmr4.gesdisc.eosdis.nasa.gov/data/MERRA2_MONTHLY/M2IMNXGAS.5.12.4/2021/MERRA2_400.instM_2d_gas_Nx.202102.nc4 MERRA2_400.instM_2d_gas_Nx.202102.nc4
# https://goldsmr4.gesdisc.eosdis.nasa.gov/data/MERRA2_MONTHLY/M2TMNXLND.5.12.4/2021/MERRA2_400.tavgM_2d_lnd_Nx.202102.nc4 MERRA2_400.tavgM_2d_lnd_Nx.202102.nc4
# ...

# %%
for m in inputs['202102']:
    print (m)
ds1=inputs['202102']['tavgM_2d_adg_Nx']['ds']
ds2=inputs['202102']['tavgM_2d_slv_Nx']['ds']
time = 1
#print(ds2)
time=0
lon=180
lat=180
print (ds1['time'][time], ds1['lat'][lat], ds1['lon'][lon], ds1['OCDP002'][time][lat][lon].round(15))
print (ds2['time'][time], ds2['lat'][lat], ds2['lon'][lon], ds2['TQV'][time][lat][lon])
# Out:
# tavgM_2d_adg_Nx
# tavgM_2d_aer_Nx
# tavgM_2d_chm_Nx
# tavgM_2d_flx_Nx
# instM_2d_gas_Nx
# tavgM_2d_lnd_Nx
# tavgM_2d_ocn_Nx
# tavgM_2d_rad_Nx
# tavgM_2d_slv_Nx
# 0 -1.7975103014118005e-13 -67.5 1.472e-12
# 0 -1.7975103014118005e-13 -67.5 58.722668
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:10: UserWarning: WARNING: valid_range not used since it
# cannot be safely cast to variable data type
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:11: UserWarning: WARNING: valid_range not used since it
# cannot be safely cast to variable data type

# %%
ds1=Dataset("MERRA2_400.tavgM_2d_aer_Nx.202112.nc4", "r")
ds2=Dataset("MERRA2_400.tavgM_2d_flx_Nx.202112.nc4", "r")
ds3=Dataset("MERRA2_400.tavgM_2d_slv_Nx.202112.nc4", "r")
ds4=Dataset("MERRA2_400.tavgM_2d_lnd_Nx.202112.nc4", "r")
ds5=Dataset("MERRA2_400.tavgM_2d_adg_Nx.202112.nc4", "r")
ds6=Dataset("MERRA2_400.tavgM_2d_rad_Nx.202112.nc4", "r")
ds7=Dataset("MERRA2_400.tavgM_2d_chm_Nx.202112.nc4", "r")
ds8=Dataset("MERRA2_400.tavgM_2d_ocn_Nx.202112.nc4", "r")
ds9=Dataset("MERRA2_400.instM_2d_gas_Nx.202112.nc4", "r")

# %%
ds4['BASEFLOW'].set_auto_mask(False)
#print (ds4['BASEFLOW']._FillValue)
a=ds4['BASEFLOW'][:]
a[a == ds4['BASEFLOW']._FillValue] = np.nan
#print (a[0][-34])
#print (ds4['BASEFLOW'], ds4['BASEFLOW'][0][35])
#np.savetxt('test.tsv', a.flatten(), delimiter='~', newline="\n")
ctr=0
for v in sorted(vars):
    if ctr == 87:
        print (v)
    ctr+=1
#print (ds2)
print(ds4['ECHANGE'])
# Out:
# ECHANGE
# <class 'netCDF4._netCDF4.Variable'>
# float32 ECHANGE(time, lat, lon)
#     long_name: rate_of_change_of_total_land_energy
#     units: W m-2
#     _FillValue: 1000000000000000.0
#     missing_value: 1000000000000000.0
#     fmissing_value: 1000000000000000.0
#     vmax: 1000000000000000.0
#     vmin: -1000000000000000.0
#     valid_range: [-1.e+15  1.e+15]
# unlimited dimensions: time
# current shape = (1, 361, 576)
# filling on

# %%
#ds4['BASEFLOW'].set_auto_mask(False)
print (ds4['BASEFLOW'].ncattrs())
#a=ds4['BASEFLOW'][:]
#a[a == ds4['BASEFLOW']._FillValue] = np.nan
#print (a[0][-34])
#print (ds4['BASEFLOW'], ds4['BASEFLOW'][0][35])
#np.savetxt('test.tsv', a.flatten(), delimiter='~', newline="\n")


vars={}
for v in ds1.variables:
    ds1[v].set_auto_mask(False)
    if '_FillValue' in ds1[v].ncattrs():
        tmp=ds1[v][:]
        tmp[tmp == ds1[v]._FillValue] = np.nan
        vars[v]=tmp[:]
    else:
        vars[v]=ds1[v][:]

for v in ds2.variables:
    if v in vars:
        print ('duplicate variable: ', v, ' skipping ....')
    else:
        ds2[v].set_auto_mask(False)
        if '_FillValue' in ds2[v].ncattrs():
            tmp=ds2[v][:]
            tmp[tmp == ds2[v]._FillValue] = np.nan
            vars[v]=tmp[:]
        else:
            vars[v]=ds2[v][:]

for v in ds3.variables:
    if v in vars:
        print ('duplicate variable: ', v, ' skipping ....')
    else:
        ds3[v].set_auto_mask(False)
        if '_FillValue' in ds3[v].ncattrs():
            tmp=ds3[v][:]
            tmp[tmp == ds3[v]._FillValue] = np.nan
            vars[v]=tmp[:]
        else:
            vars[v]=ds3[v][:]
        
for v in ds4.variables:
    if v in vars:
        print ('duplicate variable: ', v, ' skipping ....')
    else:
        ds4[v].set_auto_mask(False)
        if '_FillValue' in ds4[v].ncattrs():
            tmp=ds4[v][:]
            tmp[tmp == ds4[v]._FillValue] = np.nan
            vars[v]=tmp[:]
        else:
            vars[v]=ds4[v][:]
    if v == 'ECHANGE':
        print (vars[v])

for v in ds5.variables:
    if v in vars:
        print ('duplicate variable: ', v, ' skipping ....')
    else:
        ds5[v].set_auto_mask(False)
        if '_FillValue' in ds5[v].ncattrs():
            tmp=ds5[v][:]
            tmp[tmp == ds5[v]._FillValue] = np.nan
            vars[v]=tmp[:]
        else:
            vars[v]=ds5[v][:]

for v in ds6.variables:
    if v in vars:
        print ('duplicate variable: ', v, ' skipping ....')
    else:
        ds6[v].set_auto_mask(False)
        if '_FillValue' in ds6[v].ncattrs():
            tmp=ds6[v][:]
            tmp[tmp == ds6[v]._FillValue] = np.nan
            vars[v]=tmp[:]
        else:
            vars[v]=ds6[v][:]

for v in ds7.variables:
    if v in vars:
        print ('duplicate variable: ', v, ' skipping ....')
    else:
        ds7[v].set_auto_mask(False)
        if '_FillValue' in ds7[v].ncattrs():
            tmp=ds7[v][:]
            tmp[tmp == ds7[v]._FillValue] = np.nan
            vars[v]=tmp[:]
        else:
            vars[v]=ds7[v][:]

for v in ds8.variables:
    if v in vars:
        print ('duplicate variable: ', v, ' skipping ....')
    else:
        ds8[v].set_auto_mask(False)
        if '_FillValue' in ds8[v].ncattrs():
            tmp=ds8[v][:]
            tmp[tmp == ds8[v]._FillValue] = np.nan
            vars[v]=tmp[:]
        else:
            vars[v]=ds8[v][:]

for v in ds9.variables:
    if v in vars:
        print ('duplicate variable: ', v, ' skipping ....')
    else:
        ds9[v].set_auto_mask(False)
        if '_FillValue' in ds9[v].ncattrs():
            tmp=ds9[v][:]
            tmp[tmp == ds9[v]._FillValue] = np.nan
            vars[v]=tmp[:]
        else:
            vars[v]=ds9[v][:]
# Out:
# ['long_name', 'units', '_FillValue', 'missing_value', 'fmissing_value', 'vmax', 'vmin', 'valid_range']
# duplicate variable:  lon  skipping ....
# duplicate variable:  lat  skipping ....
# duplicate variable:  time  skipping ....
# duplicate variable:  lon  skipping ....
# duplicate variable:  lat  skipping ....
# duplicate variable:  time  skipping ....
# duplicate variable:  DISPH  skipping ....
# duplicate variable:  Var_DISPH  skipping ....
# duplicate variable:  lon  skipping ....
# duplicate variable:  lat  skipping ....
# duplicate variable:  time  skipping ....
# [[[nan nan nan ... nan nan nan]
#   [nan nan nan ... nan nan nan]
#   [nan nan nan ... nan nan nan]
#   ...
#   [nan nan nan ... nan nan nan]
#   [nan nan nan ... nan nan nan]
#   [nan nan nan ... nan nan nan]]]
# duplicate variable:  lon  skipping ....
# duplicate variable:  lat  skipping ....
# duplicate variable:  time  skipping ....
# duplicate variable:  lon  skipping ....
# ...

# %%
# Normalize lat/lon
vm_lon, vm_lat = np.meshgrid(vars['lon'], vars['lat'])
print (vm_lat.shape, vm_lon)

# Normalize time

v_time = nc.num2date(vars['time'][:],ds2['time'].units, only_use_python_datetimes=True)
print (v_time)
vm_time=np.zeros(207936, dtype='datetime64[s]')
vm_time[:]= v_time

print (vm_time[0])

# string for filename
s_time=[]
for t in v_time:
    s_time.append(t.strftime("%Y-%m-%d %H:%M:%S").replace( ' ', 'T'))
print (s_time)


t_size=vars['time'].size
for t in range(t_size):
    #print (t)
    stack_this = []
    ctr=0
    for v in sorted(vars):
        #print (ctr, v, vars[v].shape)
        ctr+=1
        if v == 'time':
            vm_time[:] = vm_time
            print ('vmtime', vm_time.shape)
            stack_this.append(vm_time.astype('float'))
        elif v == 'lon':
            stack_this.append(vm_lon.flatten()[:])
        elif v == 'lat':
            stack_this.append(vm_lat.flatten()[:])
        else:
            stack_this.append(vars[v][t].flatten()[:])
    #print (stack_this)
    x=np.dstack( (stack_this) )
    fname = '/home/ec2-user/merra2-2d_monthly' + s_time[t].replace(':', '_') + '.tsv.gz'
    np.savetxt(fname, x[0], fmt='%.12f', delimiter='~', newline="\n")
#    np.savetxt(fname, x[0], fmt='%.5f', delimiter='~', newline="\n")
    print (x.shape)
# Out:
# (361, 576) [[-180.    -179.375 -178.75  ...  178.125  178.75   179.375]
#  [-180.    -179.375 -178.75  ...  178.125  178.75   179.375]
#  [-180.    -179.375 -178.75  ...  178.125  178.75   179.375]
#  ...
#  [-180.    -179.375 -178.75  ...  178.125  178.75   179.375]
#  [-180.    -179.375 -178.75  ...  178.125  178.75   179.375]
#  [-180.    -179.375 -178.75  ...  178.125  178.75   179.375]]
# [cftime.DatetimeGregorian(2021, 12, 1, 0, 30, 0, 0)]
# 2021-12-01T00:30:00
# ['2021-12-01T00:30:00']
# vmtime (207936,)
# (1, 207936, 735)

# %%
f = open("merra2-2d-monthly_create_table.sql", "a")
f.write('CREATE EXTERNAL TABLE merra_2d_month (\n')

# Need to manually remove the comma on the last column name.

for v in sorted(vars):
    f.write(v + ' string,\n')

f.write(""" )
ROW FORMAT SERDE 
  'org.apache.hadoop.hive.serde2.OpenCSVSerde' 
WITH SERDEPROPERTIES ( 
  'quoteChar'='\u0000', 
  'separatorChar'='~') 
STORED AS INPUTFORMAT 
  'org.apache.hadoop.mapred.TextInputFormat' 
OUTPUTFORMAT 
  'org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat'
LOCATION
  's3://nasa-ems-sandbox/staging/science/merra-2/2d_month'
""")

f.close()

# %%
sql = 'select\n' 
for v in sorted(vars):
    sql += 'try_cast(' + v + '  as real) ' + v + ',\n'
sql += 'from sci_staging\n'
print (sql)
# Out:
# select
# try_cast(ALBEDO  as real) ALBEDO,
# try_cast(ALBNIRDF  as real) ALBNIRDF,
# try_cast(ALBNIRDR  as real) ALBNIRDR,
# try_cast(ALBVISDF  as real) ALBVISDF,
# try_cast(ALBVISDR  as real) ALBVISDR,
# try_cast(AODANA  as real) AODANA,
# try_cast(AODINC  as real) AODINC,
# try_cast(BASEFLOW  as real) BASEFLOW,
# try_cast(BCANGSTR  as real) BCANGSTR,
# try_cast(BCCMASS  as real) BCCMASS,
# try_cast(BCDP001  as real) BCDP001,
# try_cast(BCDP002  as real) BCDP002,
# try_cast(BCEM001  as real) BCEM001,
# try_cast(BCEM002  as real) BCEM002,
# try_cast(BCEMAN  as real) BCEMAN,
# try_cast(BCEMBB  as real) BCEMBB,
# try_cast(BCEMBF  as real) BCEMBF,
# try_cast(BCEXTTAU  as real) BCEXTTAU,
# try_cast(BCFLUXU  as real) BCFLUXU,
# try_cast(BCFLUXV  as real) BCFLUXV,
# try_cast(BCHYPHIL  as real) BCHYPHIL,
# try_cast(BCSCATAU  as real) BCSCATAU,
# try_cast(BCSD001  as real) BCSD001,
# try_cast(BCSD002  as real) BCSD002,
# try_cast(BCSMASS  as real) BCSMASS,
# ...

# %%
v_time = nc.num2date(ds2['time'][:],ds2['time'].units, only_use_python_datetimes=True)
v_lev  = ds2['lev'][:]
v_lon  = ds2['lon'][:]
v_lat  = ds2['lat'][:]
v_CLOUD = np.around(ds2['CLOUD'][:],7)
v_DELP = np.around(ds2['DELP'][:],7 )
v_EPV = np.around(ds2['EPV'][:], 7)
v_H = np.around(ds2['H'][:], 7)
v_O3 = np.around(ds2['O3'][:], 7)
v_OMEGA = np.around(ds2['OMEGA'][:], 7)
v_PHIS = np.around(ds2['PHIS'][:], 7)
v_PL = np.around(ds2['PL'][:], 7)
v_PS = ds2['PS'][:]
v_QI = ds2['QI'][:]
v_QL = ds2['QL'][:]
v_QV = ds2['QV'][:]
v_RH = ds2['RH'][:]
v_SLP = np.around(ds2['SLP'][:],7)
v_T = ds2['T'][:]
v_U = ds2['U'][:]
v_V = ds2['V'][:]
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:1: UserWarning: WARNING: valid_range not used since it
# cannot be safely cast to variable data type
#   if __name__ == '__main__':

# %%
import datetime
print (v_time)
#print (v_time[0].replace())
#x=v_time[0].strftime("%Y-%m-%d %H:%M:%S")
#print (x, type(x))
#y=datetime.datetime.strptime(x,"%Y-%m-%d %H:%M:%S")
#print (y, type(y))
#print (z, type(z))
s_time=[]
for t in v_time:
    s_time.append(t.strftime("%Y-%m-%d %H:%M:%S").replace( ' ', 'T'))

print (s_time)
# Out:
# [cftime.DatetimeGregorian(2021, 12, 31, 0, 0, 0, 0, has_year_zero=False)
#  cftime.DatetimeGregorian(2021, 12, 31, 3, 0, 0, 0, has_year_zero=False)
#  cftime.DatetimeGregorian(2021, 12, 31, 6, 0, 0, 0, has_year_zero=False)
#  cftime.DatetimeGregorian(2021, 12, 31, 9, 0, 0, 0, has_year_zero=False)
#  cftime.DatetimeGregorian(2021, 12, 31, 12, 0, 0, 0, has_year_zero=False)
#  cftime.DatetimeGregorian(2021, 12, 31, 15, 0, 0, 0, has_year_zero=False)
#  cftime.DatetimeGregorian(2021, 12, 31, 18, 0, 0, 0, has_year_zero=False)
#  cftime.DatetimeGregorian(2021, 12, 31, 21, 0, 0, 0, has_year_zero=False)]
# ['2021-12-31T00:00:00', '2021-12-31T03:00:00', '2021-12-31T06:00:00', '2021-12-31T09:00:00', '2021-12-31T12:00:00', '2021-12-31T15:00:00', '2021-12-31T18:00:00', '2021-12-31T21:00:00']

# %%
#lon=[-180, -90, 0, 90, 180]
#lat=[-90, 0, 90]
#m_lat,m_lon = np.meshgrid(lat,lon)
#print (m_lon.shape, m_lon)
#print (m_lat.shape, m_lat)

# %%
#print ('1', np.repeat([[1,2],[3,4]], 2))
#x = np.array( [[1,2],[3,4]] )
#print ('2a', np.repeat(x, 2))
#[     C C
#R    [1,2],
#R    [3,4]
#]
#print ('2b', np.repeat(x, 5, axis=1))
#print ('2c', np.repeat(x, 5, axis=0))
#print ('3', np.repeat(x, 3, axis=1))
#print ('4', np.repeat(x, [1, 2], axis=0))
#y=np.zeros((5, 2, 2))
#print (x.shape, y.shape)
#for i in range(5):
#    y[i]=x
#print (y[0])

vn_PHIS=np.zeros((72,361,576))
vn_PS=np.zeros((72,361,576))
vn_SLP=np.zeros((72,361,576))

for i in range(72):
    vn_PHIS[i]=v_PHIS[0]
    vn_PS[i]=v_PS[0]
    vn_SLP[i]=v_SLP[0]

print (vn_PS.shape)
# Out:
# (72, 361, 576)

# %%
charar = np.chararray(100, itemsize=19)
charar[:] = s_time[0]
#print (charar)
d = np.zeros(10, dtype='datetime64[s]')
#print (d)
d[:]=v_time[0]
print (d)
# Out:
# ['2021-12-31T00:00:00' '2021-12-31T00:00:00' '2021-12-31T00:00:00'
#  '2021-12-31T00:00:00' '2021-12-31T00:00:00' '2021-12-31T00:00:00'
#  '2021-12-31T00:00:00' '2021-12-31T00:00:00' '2021-12-31T00:00:00'
#  '2021-12-31T00:00:00']

# %%
#vf_CLOUD = v_CLOUD.flatten()
#vf_H     = v_H.flatten()
#print (v_SLP.shape)
#X, Y = np.meshgrid(x*geo_var.perspective_point_height, y*geo_var.perspective_point_height)
#vm_lon, vm_lat = np.meshgrid(v_lon, v_lat)
print (vn_PHIS.shape, v_PL.shape)


vm_time=np.zeros(14971392, dtype='datetime64[s]')

vm_lat, vm_lev, vm_lon = np.meshgrid(v_lat, v_lev, v_lon)


t_size=v_time.size

for t in range(t_size):
#    print (vn_SLP[t].shape)
#    print (t, v_time[t])
#    print (vm_lat.shape, vm_lon.shape)
#    print (vn_PS.shape, vn_PS[t].shape)
    
    vm_time[:] = v_time[t]
    print (vm_time.shape)
    x=np.dstack((
        vm_lon.flatten(), 
        vm_lat.flatten(), 
        vm_lev.flatten(),
        vm_time.astype('float'),
        v_CLOUD[t].flatten(), 
        v_DELP[t].flatten(),
        v_EPV[t].flatten(),
        v_H[t].flatten(),
        v_O3[t].flatten(),
        v_OMEGA[t].flatten(),
        vn_PHIS.flatten(), 
        v_PL[t].flatten(), 
        vn_PS.flatten(), 
        v_QI[t].flatten(), 
        v_QL[t].flatten(), 
        v_QV[t].flatten(), 
        v_RH[t].flatten(), 
        vn_SLP.flatten(), 
        v_T[t].flatten(), 
        v_U[t].flatten(), 
        v_V[t].flatten()
    ))
    fname = '/home/ec2-user/test' + s_time[t].replace(':', '_') + '.tsv.gz'
    np.savetxt(fname, x[0], fmt='%.5f', delimiter='~', newline="\n")
# Out:
# (72, 361, 576) (8, 72, 361, 576)
# (14971392,)
# (14971392,)
# (14971392,)
# (14971392,)
# (14971392,)
# (14971392,)
# (14971392,)
# (14971392,)

# %%
np.savetxt('test.tsv.gz', x[0], fmt='%.5f', delimiter='~', newline="\n")

# %%
print (x.shape)
for i in range(x.size):
    v_x=x[0][i]
    print (i, v_x)
    #np.savetxt('test.tsv', v_x, fmt='%.5f', delimeter='~', newline="\n")
    break
print (i, x.shape)
print (x[0][0].min())
# Out:
# (1, 14971392, 8)
# 0 [-1.80000000e+02 -9.00000000e+01  1.00000000e+00  2.75777090e+04
#   6.86709297e+04  9.97232578e+04  0.00000000e+00  1.00000024e+00]
# 0 (1, 14971392, 8)
# -180.0

# %%
#for l in range(v_lev.size):
#    print (l, v_lev[l])
    
lon=1
lat=140
level=1
print (v_T[0][level][lat][lon])
# Out:
# 205.59442

# %%
v_time = nc.num2date(ds2['time'][:],ds2['time'].units, only_use_python_datetimes=True)
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:1: UserWarning: WARNING: valid_range not used since it
# cannot be safely cast to variable data type
#   if __name__ == '__main__':
